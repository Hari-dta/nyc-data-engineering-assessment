# %%
import findspark
findspark.init()

# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *

spark = SparkSession.builder. \
    appName("pyspark-1"). \
    getOrCreate()

# %% [markdown]
# ### Read data

# %%
df = spark.read.csv("/dataset/nyc-jobs.csv", header=True,inferSchema=True)
df.printSchema()
# Out:
# root
#  |-- Job ID: integer (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Posting Type: string (nullable = true)
#  |-- # Of Positions: integer (nullable = true)
#  |-- Business Title: string (nullable = true)
#  |-- Civil Service Title: string (nullable = true)
#  |-- Title Code No: string (nullable = true)
#  |-- Level: string (nullable = true)
#  |-- Job Category: string (nullable = true)
#  |-- Full-Time/Part-Time indicator: string (nullable = true)
#  |-- Salary Range From: double (nullable = true)
#  |-- Salary Range To: double (nullable = true)
#  |-- Salary Frequency: string (nullable = true)
#  |-- Work Location: string (nullable = true)
#  |-- Division/Work Unit: string (nullable = true)
#  |-- Job Description: string (nullable = true)
#  |-- Minimum Qual Requirements: string (nullable = true)
#  |-- Preferred Skills: string (nullable = true)
#  |-- Additional Information: string (nullable = true)
#  |-- To Apply: string (nullable = true)
#  |-- Hours/Shift: string (nullable = true)
#  |-- Work Location 1: string (nullable = true)
#  |-- Recruitment Contact: string (nullable = true)
#  |-- Residency Requirement: string (nullable = true)
#  |-- Posting Date: string (nullable = true)
#  |-- Post Until: string (nullable = true)
#  |-- Posting Updated: string (nullable = true)
#  |-- Process Date: string (nullable = true)

# %% [markdown]
# ### clean data

# %%
def clean_and_normalize_df(df):

    for column in df.columns:
        df = df.withColumn(column, trim(col(column)))

    for column in df.columns:
        new_col = column.lower().replace(" ", "_").replace("/", "_")
        df = df.withColumnRenamed(column, new_col)

    df = (
        df.withColumn("salary_range_from", col("salary_range_from").cast(DoubleType()))
          .withColumn("salary_range_to", col("salary_range_to").cast(DoubleType()))
    )

    df = df.withColumn("salary_frequency", upper(col("salary_frequency")))

    df = df.withColumn(
        "posting_date",
        to_date(col("posting_date"), "yyyy-MM-dd")
    )

    df = df.withColumn(
        "salary_midpoint",
        (col("salary_range_from") + col("salary_range_to")) / 2
    )

    df = df.withColumn(
        "annual_salary",
        when(col("salary_frequency") == "HOURLY",
             col("salary_midpoint") * 2080)
        .when(col("salary_frequency") == "DAILY",
              col("salary_midpoint") * 260)
        .otherwise(col("salary_midpoint"))
    )

    df = df.filter(
        (col("annual_salary").isNotNull()) &
        (col("annual_salary") > 0)
    )

    if "job_id" in df.columns:
        df = df.dropDuplicates(["job_id"])
    else:
        df = df.dropDuplicates()

    return df

df_clean = clean_and_normalize_df(df)

df_clean.printSchema()
#df_clean.show(truncate = False)
# Out:
# root
#  |-- job_id: string (nullable = true)
#  |-- agency: string (nullable = true)
#  |-- posting_type: string (nullable = true)
#  |-- #_of_positions: string (nullable = true)
#  |-- business_title: string (nullable = true)
#  |-- civil_service_title: string (nullable = true)
#  |-- title_code_no: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- job_category: string (nullable = true)
#  |-- full-time_part-time_indicator: string (nullable = true)
#  |-- salary_range_from: double (nullable = true)
#  |-- salary_range_to: double (nullable = true)
#  |-- salary_frequency: string (nullable = true)
#  |-- work_location: string (nullable = true)
#  |-- division_work_unit: string (nullable = true)
#  |-- job_description: string (nullable = true)
#  |-- minimum_qual_requirements: string (nullable = true)
#  |-- preferred_skills: string (nullable = true)
#  |-- additional_information: string (nullable = true)
#  |-- to_apply: string (nullable = true)
#  |-- hours_shift: string (nullable = true)
#  |-- work_location_1: string (nullable = true)
#  |-- recruitment_contact: string (nullable = true)
#  |-- residency_requirement: string (nullable = true)
#  |-- posting_date: date (nullable = true)
#  |-- post_until: string (nullable = true)
#  |-- posting_updated: string (nullable = true)
#  |-- process_date: string (nullable = true)
#  |-- salary_midpoint: double (nullable = true)
#  |-- annual_salary: double (nullable = true)

# %% [markdown]
# ## KPIs

# %% [markdown]
# ### 1.Whats the number of jobs posting per category (Top 10)?

# %%
kpi1 = (
    df_clean.groupBy("job_category")
            .count()
            .orderBy(col("count").desc())
            .limit(10)
)

kpi1.show(truncate=False)
# Out:
# +-----------------------------------------+-----+
# |job_category                             |count|
# +-----------------------------------------+-----+
# |Engineering, Architecture, & Planning    |260  |
# |Technology, Data & Innovation            |182  |
# |Legal Affairs                            |120  |
# |Building Operations & Maintenance        |99   |
# |Finance, Accounting, & Procurement       |98   |
# |Public Safety, Inspections, & Enforcement|98   |
# |Administration & Human Resources         |88   |
# |Health                                   |71   |
# |Constituent Services & Community Programs|68   |
# |Policy, Research & Analysis              |64   |
# +-----------------------------------------+-----+

# %% [markdown]
# ### 2.Whats the salary distribution per job category?

# %%
kpi2 = (
    df_clean.groupBy("job_category")
            .agg(
                avg("annual_salary").alias("avg_salary"),
                min("annual_salary").alias("min_salary"),
                max("annual_salary").alias("max_salary")
            )
            .orderBy(col("avg_salary").desc())
)

kpi2.show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+------------------+------------------+
# |job_category                                                                                                                                                                                             |avg_salary        |min_salary        |max_salary        |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+------------------+------------------+
# |Administration & Human Resources Finance, Accounting, & Procurement Building Operations & Maintenance                                                                                                    |218587.0          |218587.0          |218587.0          |
# |Engineering, Architecture, & Planning Maintenance & Operations                                                                                                                                           |198518.0          |198518.0          |198518.0          |
# |Engineering, Architecture, & Planning Finance, Accounting, & Procurement Building Operations & Maintenance Public Safety, Inspections, & Enforcement                                                     |196042.5          |182500.0          |209585.0          |
# |Health Policy, Research & Analysis Public Safety, Inspections, & Enforcement                                                                                                                             |128694.5          |94889.0           |162500.0          |
# |Engineering, Architecture, & Planning Technology, Data & Innovation Public Safety, Inspections, & Enforcement                                                                                            |128247.5          |128247.5          |128247.5          |
# |Engineering, Architecture, & Planning Policy, Research & Analysis Public Safety, Inspections, & Enforcement                                                                                              |128247.5          |128247.5          |128247.5          |
# |Communications & Intergovernmental Affairs Engineering, Architecture, & Planning Technology, Data & Innovation Policy, Research & Analysis                                                               |125000.0          |125000.0          |125000.0          |
# |Constituent Services & Community Programs Finance, Accounting, & Procurement Policy, Research & Analysis Social Services                                                                                 |122182.31999999999|122182.31999999999|122182.31999999999|
# |Administration & Human Resources Finance, Accounting, & Procurement Technology, Data & Innovation Building Operations & Maintenance Policy, Research & Analysis Public Safety, Inspections, & Enforcement|118287.0          |118287.0          |118287.0          |
# |Constituent Services & Community Programs Communications & Intergovernmental Affairs Policy, Research & Analysis                                                                                         |116900.33333333333|58500.0           |217201.0          |
# |Constituent Services & Community Programs Communications & Intergovernmental Affairs Social Services                                                                                                     |103680.5          |103680.5          |103680.5          |
# |Engineering, Architecture, & Planning Building Operations & Maintenance Public Safety, Inspections, & Enforcement                                                                                        |98257.8           |69283.5           |140171.2          |
# |Technology, Data & Innovation Social Services                                                                                                                                                            |95939.0625        |39119.0           |112527.5          |
# |Administration & Human Resources Communications & Intergovernmental Affairs Engineering, Architecture, & Planning Policy, Research & Analysis                                                            |95000.0           |95000.0           |95000.0           |
# |Administration & Human Resources Constituent Services & Community Programs Policy, Research & Analysis Social Services                                                                                   |94448.0           |32240.0           |110000.0          |
# |Administration & Human Resources Finance, Accounting, & Procurement Policy, Research & Analysis                                                                                                          |92500.0           |92500.0           |92500.0           |
# |Technology, Data & Innovation                                                                                                                                                                            |91256.62657142857 |32957.6           |169011.0          |
# |Administration & Human Resources Constituent Services & Community Programs                                                                                                                               |91000.0           |55000.0           |100000.0          |
# |Administration & Human Resources Constituent Services & Community Programs Legal Affairs                                                                                                                 |90000.0           |90000.0           |90000.0           |
# |Engineering, Architecture, & Planning Public Safety, Inspections, & Enforcement                                                                                                                          |89730.0           |51483.0           |124970.0          |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3. Is there any correlation between the higher degree and the salary?

# %%
df_degree = df_clean.withColumn(
    "degree_level",
    when(col("minimum_qual_requirements").rlike("PhD|Doctor"), 3)
    .when(col("minimum_qual_requirements").rlike("Master"), 2)
    .when(col("minimum_qual_requirements").rlike("Bachelor"), 1)
    .otherwise(0)
)

correlation = df_degree.stat.corr("degree_level", "annual_salary")

print("Correlation:", correlation)

has_positive_correlation = correlation is not None and correlation > 0

print("Is there positive correlation between degree and salary? ->",
      "Yes" if has_positive_correlation else "No")
# Out:
# Correlation: 0.06428680045265775
# Is there positive correlation between degree and salary? -> Yes

# %% [markdown]
# ### 4.Whats the job posting having the highest salary per agency?

# %%
kpi4 = (
    df_clean.groupBy("agency")
            .agg(max("annual_salary").alias("highest_salary"))
            .orderBy(col("highest_salary").desc())
)

kpi4.show(truncate=False)
# Out:
# +------------------------------+------------------+
# |agency                        |highest_salary    |
# +------------------------------+------------------+
# |DEPT OF ENVIRONMENT PROTECTION|218587.0          |
# |POLICE DEPARTMENT             |217201.0          |
# |DISTRICT ATTORNEY KINGS COUNTY|191913.0          |
# |NYC HOUSING AUTHORITY         |180000.0          |
# |NYC EMPLOYEES RETIREMENT SYS  |177374.5          |
# |DEPT OF HEALTH/MENTAL HYGIENE |170133.84         |
# |OFFICE OF THE COMPTROLLER     |167500.0          |
# |DEPARTMENT OF INVESTIGATION   |165000.0          |
# |LAW DEPARTMENT                |164104.0          |
# |DEPARTMENT OF SANITATION      |158038.4          |
# |DEPT OF DESIGN & CONSTRUCTION |151795.0          |
# |DEPARTMENT FOR THE AGING      |150371.0          |
# |DEPT OF CITYWIDE ADMIN SVCS   |140171.2          |
# |TAXI & LIMOUSINE COMMISSION   |140000.0          |
# |DEPARTMENT OF CORRECTION      |139105.09600000002|
# |DEPT OF INFO TECH & TELECOMM  |138968.0          |
# |CONFLICTS OF INTEREST BOARD   |135000.0          |
# |FINANCIAL INFO SVCS AGENCY    |135000.0          |
# |HOUSING PRESERVATION & DVLPMNT|135000.0          |
# |DEPT OF PARKS & RECREATION    |128000.0          |
# +------------------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### 5.Whats the job positings average salary per agency for the last 2 years?

# %%
latest_year = (
    df_clean
    .filter(col("posting_date").isNotNull())
    .select(year(col("posting_date")).alias("year"))
    .agg(max("year"))
    .collect()[0][0]
)

kpi5 = (
    df_clean.filter(year(col("posting_date")) >= latest_year - 2)
            .groupBy("agency")
            .agg(avg("annual_salary").alias("avg_salary"))
            .orderBy(col("avg_salary").desc())
)

kpi5.show(truncate=False)
# Out:
# +------------------------------+------------------+
# |agency                        |avg_salary        |
# +------------------------------+------------------+
# |CONFLICTS OF INTEREST BOARD   |135000.0          |
# |FIRE DEPARTMENT               |108140.93333333333|
# |BUSINESS INTEGRITY COMMISSION |95000.0           |
# |FINANCIAL INFO SVCS AGENCY    |93994.5           |
# |DEPARTMENT OF SANITATION      |90029.71          |
# |DEPT OF INFO TECH & TELECOMM  |88313.03448275862 |
# |MAYORS OFFICE OF CONTRACT SVCS|87357.14285714286 |
# |OFFICE OF THE COMPTROLLER     |85235.71428571429 |
# |HOUSING PRESERVATION & DVLPMNT|84882.17857142857 |
# |CONSUMER AFFAIRS              |82550.66666666667 |
# |PRESIDENT BOROUGH OF MANHATTAN|82500.0           |
# |HUMAN RIGHTS COMMISSION       |82444.9485        |
# |DEPT OF YOUTH & COMM DEV SRVS |80697.875         |
# |DEPT OF CITYWIDE ADMIN SVCS   |79921.2888888889  |
# |DEPARTMENT OF PROBATION       |79175.64          |
# |LAW DEPARTMENT                |79054.03726829268 |
# |NYC HOUSING AUTHORITY         |78524.65135135135 |
# |DEPT OF DESIGN & CONSTRUCTION |77807.171875      |
# |DEPARTMENT OF CITY PLANNING   |77133.33333333333 |
# |DEPARTMENT OF BUSINESS SERV.  |74779.21942857142 |
# +------------------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### 6.What are the highest paid skills in the US market?

# %%
df_skills = df_clean.withColumn(
    "skill",
    explode(split(col("preferred_skills"), ","))
)

kpi6 = (
    df_skills.groupBy("skill")
             .agg(avg("annual_salary").alias("avg_salary"))
             .orderBy(col("avg_salary").desc())
)

kpi6.show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# |skill                                                                                                                                                                                                                                                                                      |avg_salary|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# | diagnose problems                                                                                                                                                                                                                                                                         |218587.0  |
# | communication and client service skills as well as a passion for driving innovation                                                                                                                                                                                                       |218587.0  |
# | results-driven environment with equal enthusiasm for high-level strategic planning and tactical daily execution â€¢	In-depth knowledge of Federal                                                                                                                                         |218587.0  |
# | the following skills and abilities are required to be successful in this role:    â€¢	7-10 years relevant work experience leading customer focused functions                                                                                                                              |218587.0  |
# | he/she must be an effective team player                                                                                                                                                                                                                                                   |218587.0  |
# |The Deputy Commissioner position requires excellent leadership                                                                                                                                                                                                                             |218587.0  |
# | and implementing workforce strategies to recruit                                                                                                                                                                                                                                          |218587.0  |
# | and implement action plans to resolve issues â€¢	Outstanding written and oral communication skills â€¢	Comfort in managing concurrent projects in a fast-paced                                                                                                                            |218587.0  |
# | develop and retain the most qualified and diverse talent in a customer service environment. The selected candidate will be expected to work closely with Agency and oversight counterparts and must have excellent management skills focused on staff alignment with the Bureauâ€™s vision|218587.0  |
# | goals and career development. In addition                                                                                                                                                                                                                                                 |218587.0  |
# | City and State governmental rules and regulations related to the position; NYC experience is a plus. â€¢	Proficiency in Microsoft Office Suite                                                                                                                                            |218587.0  |
# | with ability to interpret data and trends                                                                                                                                                                                                                                                 |218587.0  |
# | of which at least 3 years must have been in a senior leadership position â€¢	BA/BS degree; MBA/advanced degree preferred â€¢	Strong analytical skills                                                                                                                                     |218587.0  |
# | capable of sustaining a culture of excellence in the delivery of customer service to internal partners and possess the ability to establish and maintain effective external partnerships and collaboration.   Specifically                                                                |218587.0  |
# | continuous improvement and efficiency                                                                                                                                                                                                                                                     |218587.0  |
# |all candidates must have the 3 years of administrative                                                                                                                                                                                                                                     |209585.0  |
# | including large numbers of engineering and other technical staff. A New York State grade 4A Wastewater Treatment Plant Operator Certificate is desirable.                                                                                                                                 |198518.0  |
# |Extensive experience in wastewater operations is preferred but not required. The ideal candidate will also demonstrate competency in managing technical operations                                                                                                                         |198518.0  |
# | CircleCI                                                                                                                                                                                                                                                                                  |191913.0  |
# | PostgreSQL                                                                                                                                                                                                                                                                                |191913.0  |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# only showing top 20 rows
